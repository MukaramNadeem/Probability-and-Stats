# %% [markdown]
# ## `random variables(RVs)` are just like normal variables but they have some probability associated with them.They store the variable based on that probabiltiy.Like `P(N=n)`.`N` is the RV and `n` is the value to be stored , `P` is the symbol of probability.

# %% [markdown]
# ### We cannot assign value to `N` but we can assign value to `n`.

# %% [markdown]
# ### `N` is a `discrete` random variable

# %% [markdown]
# ### `Distributions` It is to take total probability as 1 (as we always do) and distribute it among all events.

# %% [markdown]
# ### `Frequentist` view of probability is to divide the frequency of individual element to the total number of elements to calculate the probability of that element.

# %% [markdown]
# ### `Probability frequency distribution??? (PFD)`
# Frequency distributon & Comulative Frequency distribution table and graphs???

# %% [markdown]
# ### Discrete vs Continuous random variables.

# %% [markdown]
# ### A piece wise function is converted into probability density function.

# %% [markdown]
# ### Putting the value in probability density functions (PDF) once, we get the bernoulli distribution.

# %% [markdown]
# Then when we do n number of experiments to calculate the value of X (random variable that counts probability of 1 or true for n experiments) then we come up with `Binomial Distribution`.

# %% [markdown]
# ### ALL this is just to know the behaviour of random variable X. Which is Discrete `not` continuous till now

# %% [markdown]
# ##### Piosson and geometric are the other types of such distributions for discrete random variable.

# %% [markdown]
# # Code :  Discributions

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
import datetime

# %% [markdown]
# # Bernoulli Distribution

# %%
from scipy.stats import bernoulli

# %%
data = bernoulli.rvs(size = 1000 , p=0.6 )

# %%
ax = sns.histplot(data,bins=100,kde = False)
ax.set(xlabel = "bernoulli distribution" , ylabel = "Frequency")
# Out:
# [Text(0.5, 0, 'bernoulli distribution'), Text(0, 0.5, 'Frequency')]

# %%
#print(data)

# %% [markdown]
# # Poisson Distribution

# %%
from scipy.stats import poisson

# %%
data = poisson.rvs(mu = 3 , size = 10000)

# %%
ax = sns.histplot(data,bins=50,kde= False)
ax.set(xlabel = "Poisson Distribution" , ylabel = "Frequency")
# Out:
# [Text(0.5, 0, 'Poisson Distribution'), Text(0, 0.5, 'Frequency')]
